# %% [markdown]
# <a href="https://colab.research.google.com/github/simulate111/Acquisition-and-Analysis-of-Biosignals/blob/main/Ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
