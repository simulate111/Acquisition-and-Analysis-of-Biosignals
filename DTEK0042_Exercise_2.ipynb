# %% [markdown]
# <a href="https://colab.research.google.com/github/simulate111/Acquisition-and-Analysis-of-Biosignals/blob/main/DTEK0042_Exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DTEK0042 Exercise 2
#
#         Name:
#         Email:

# %% [markdown]
# *** Note for Google Colab Users ***
#      Because Google Colab doesn't have a button to convert your notebook to .html format here is a quick work around:
#    1. open a new google colab notebook
#    2. in the files section in google colab, upload the .ipynb file you want to be converted to .html
#    3. in your new open notebook run this command in an empty cell: !jupyter nbconvert --to html YourFileName.ipynb
#    4. after the command is finished running refresh the page
#    5. In your files section you should see your original .ipynb file that you uploaded and then a .html file of that same notebook.
#    6. download the .html file and you're good to go!

# %% [markdown]
# In this exercise, you are required to analyze an ECG signal step-by-step as outlined below. The deliverables for this exercise are a jupyter notebook in both .ipynb and .html format. Please provide caption for every figure and include description for every figure.

# %% [markdown]
# ## library Imports

# %%
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Import and plotting
# * Import the ECG signal named “ECG_800Hz.txt” into your python environment and store it in a variable named “ECG_sig”.
# * Plot the signal
# * Note: the sampling frequency of this signal is 800Hz.
# * You need this value if you want to plot ECG versus time.
#
#
#      HINT: ECG_sig = np.loadtxt(the directory of the ECG signal)
#      https://numpy.org/doc/stable/reference/generated/numpy.loadtxt.html

# %%
#code

# %% [markdown]
# # Discrete Fourier Transform
#
#  * Compute DFT using FFT algorithm provided by scipy package. Take only the positive frequencies from the computed DFT and subsequently calculate the magnitude (absolute value) of frequency content. Plot the calculated magnitude versus frequency.
#  * Discard the frequencies below 0.5Hz and above 40Hz and replot the magnitude versus frequency.
#
#
#      * HINT use scipy.fft.rfft() outputs positive portion of function
#
#      https://docs.scipy.org/doc/scipy/reference/generated/scipy.fft.rfft.html
#      https://docs.scipy.org/doc/scipy/reference/generated/scipy.fft.rfftfreq.html

# %%
# code

# %% [markdown]
# # Band Pass Filter Design
# *  Design a band pass filter. Use Butterworth filter of order 4 with cutoff frequencies equal to 0.5Hz and 40Hz.
#
#
# * Design another butterworth band pass filter but this time use an order of 2 with cutoff frequencies equal to 0.5Hz and 40Hz
#
#
# * Plot the frequency response of both filters and explain your observations
#
#
#     * Hint use the following three functions scipy.signal.butter() and scipy.signal.freqz()
#
#
# * Important to use the scipy.signal.freqz() function and NOT the scipy.signal.freqs() function.
#
#         scipy.signal.freqz() is for digital filters which is what we want.
#
# https://docs.scipy.org/doc/scipy/reference/signal.html#filtering link to info about scipy.signal functions

# %%
# code

# %% [markdown]
# ## Observations:

# %% [markdown]
# # Apply filter to ECG_Sig
# * Use the designed 4th order filter to filter ECG_sig and plot the first 5000 samples from the original signal (raw_signal) and the filtered signal.
# * What happens after filtering?
# * Explain your observations

# %%
#code

# %% [markdown]
# ## Observations:

# %% [markdown]
# # Plot the frequency domain of raw and filtered signal
# * Plot raw and filtered signals in the frequency domain and explain your observations
# * For each signal select frequencies from 0 to 50Hz

# %%
#code

# %% [markdown]
# ## Observations:

# %% [markdown]
# # QRS Detection
# *  QRS detection using “hamilton” method provided by the “biosppy” package.
# *  If you do not have this package installed, use the following command to install it  !pip install biosppy in the next cell
# * For google colab use following command in the cell as well: !pip install biosppy

# %%
#still need to locally install biosppy
#code
# !pip install biosppy
import biosppy
from biosppy.signals import ecg
# Out:
# Collecting biosppy
#   Downloading biosppy-2.2.4-py2.py3-none-any.whl.metadata (6.1 kB)
# Collecting bidict (from biosppy)
#   Downloading bidict-0.24.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.13/dist-packages (from biosppy) (3.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from biosppy) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from biosppy) (2.1.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.13/dist-packages (from biosppy) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from biosppy) (1.16.3)
# Collecting shortuuid (from biosppy)
#   Downloading shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.13/dist-packages (from biosppy) (1.17.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.13/dist-packages (from biosppy) (1.6.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.13/dist-packages (from biosppy) (5.0.0.93)
# Requirement already satisfied: pywavelets in /usr/local/lib/python3.13/dist-packages (from biosppy) (1.9.0)
# Collecting mock (from biosppy)
#   Downloading mock-5.2.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib->biosppy) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->biosppy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->biosppy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->biosppy) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->biosppy) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->biosppy) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->biosppy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->biosppy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->biosppy) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->biosppy) (3.6.0)
# Downloading biosppy-2.2.4-py2.py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 2.6 MB/s eta 0:00:00
# Downloading bidict-0.24.1-py3-none-any.whl (36 kB)
# Downloading mock-5.2.0-py3-none-any.whl (31 kB)
# Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Installing collected packages: shortuuid, mock, bidict, biosppy
# Successfully installed bidict-0.24.1 biosppy-2.2.4 mock-5.2.0 shortuuid-1.0.13
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_851/1398242096.py in <cell line: 0>()
#       2 #code
#       3 get_ipython().system('pip install biosppy')
# ----> 4 import biosppy
#       5 from biosppy.signals import ecg
#
# /usr/local/lib/python3.13/dist-packages/biosppy/__init__.py in <module>
#      17
#      18 # allow lazy loading
# ---> 19 from .signals import acc, abp, bvp, ppg, pcg, ecg, eda, eeg, emg, resp, tools, hrv
#      20 from .synthesizers import ecg, emg
#      21 # from .inter_plotting import ecg, acc
#
# /usr/local/lib/python3.13/dist-packages/biosppy/signals/__init__.py in <module>
#      21
#      22 # allow lazy loading
# ---> 23 from . import acc, abp, bvp, pcg, ppg, ecg, eda, eeg, emg, resp, tools
#
# /usr/local/lib/python3.13/dist-packages/biosppy/signals/pcg.py in <module>
#      22 # local
#      23 from . import tools as st
# ---> 24 from . import ecg
#      25 from .. import plotting, utils
#      26
#
# /usr/local/lib/python3.13/dist-packages/biosppy/signals/ecg.py in <module>
#      24 import matplotlib.pyplot as plt
#      25 from scipy import stats, integrate, interpolate
# ---> 26 import peakutils
#      27 from scipy.ndimage import filters
#      28
#
# ModuleNotFoundError: No module named 'peakutils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Observations:
