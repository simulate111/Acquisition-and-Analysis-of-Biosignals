# %% [markdown]
# <a href="https://colab.research.google.com/github/simulate111/Acquisition-and-Analysis-of-Biosignals/blob/main/Make_HTML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Download the .ipynb file directly from your GitHub repository using the raw link
# !wget -O dtek0042_exercise_2.ipynb https://raw.githubusercontent.com/simulate111/Acquisition-and-Analysis-of-Biosignals/7c6613758d7e1b913287bd0df4b9c510f4688e07/dtek0042_exercise_2.ipynb

# 2. Convert the downloaded notebook to HTML format
# !jupyter nbconvert --to html dtek0042_exercise_2.ipynb
# Out:
# --2026-09-20 07:34:34--  https://raw.githubusercontent.com/simulate111/Acquisition-and-Analysis-of-Biosignals/7c6613758d7e1b913287bd0df4b9c510f4688e07/dtek0042_exercise_2.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 553831 (541K) [text/plain]
# Saving to: ‘dtek0042_exercise_2.ipynb’
#
# dtek0042_exercise_2 100%[===================>] 540.85K  --.-KB/s    in 0.06s
#
# 2026-09-20 07:34:34 (8.64 MB/s) - ‘dtek0042_exercise_2.ipynb’ saved [553831/553831]
#
# [NbConvertApp] Converting notebook dtek0042_exercise_2.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 7 image(s).
# [NbConvertApp] Writing 851856 bytes to dtek0042_exercise_2.html

# %%
#!jupyter nbconvert --to html 22.ipynb
